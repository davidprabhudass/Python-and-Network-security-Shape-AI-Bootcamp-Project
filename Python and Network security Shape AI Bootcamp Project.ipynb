# %%
import hashlib

print("Convert The Given String Into MD5 Hash \n ")

Input = str(input("Enter your string for change into hashes:"))

Output = hashlib.md5(Input.encode())

print("\n______________________________________________________")

print("\n The hash values of your string: " + Output.hexdigest())

print("\n______________________________________________________")
# Out:
# Convert The Given String Into MD5 Hash
#
# Enter your string for change into hashes:David prabhu dass
#
# ______________________________________________________
#
#  The hash values of your string: b7a8e288067bbe9a2660e799a52aae84
#
# ______________________________________________________
